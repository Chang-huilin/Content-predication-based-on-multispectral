# %%
#导入必要的库
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dropout, Bidirectional, LSTM, Dense, Multiply, Input # type: ignore
from tensorflow.keras.models import Model    # type: ignore
from tensorflow.keras.optimizers import Adam

# %%
#设置LSTM的时间窗等参数
window=5
lstm_units = 16
dropout = 0.01
epoch=60
#读取数据
df1=pd.read_csv('data.csv') 
df1=df1.iloc[:,2:]
df1.tail()
# Out:
#          open     low   close    high
# 26272  7.1042  7.1042  7.1048  7.1055
# 26273  7.1047  7.1038  7.1038  7.1047
# 26274  7.1039  7.1039  7.1046  7.1047
# 26275  7.1048  7.1043  7.1045  7.1049
# 26276  7.1049  7.1049  7.1057  7.1057

# %%
#进行数据归一化
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
df0=min_max_scaler.fit_transform(df1)
df = pd.DataFrame(df0, columns=df1.columns)
input_size=len(df.iloc[1,:])

# %%
#构建lstm输入
stock=df
seq_len=window
amount_of_features = len(stock.columns)#有几列
data = stock.to_numpy() #pd.DataFrame(stock) 表格转化为矩阵
sequence_length = seq_len + 1#序列长度
result = []
for index in range(len(data) - sequence_length):#循环数据长度-sequence_length次
    result.append(data[index: index + sequence_length])#第i行到i+sequence_length
result = np.array(result)#得到样本，样本形式为6天*3特征
row = round(0.9 * result.shape[0])#划分训练集测试集
train = result[:int(row), :]
x_train = train[:, :-1]
y_train = train[:, -1][:,-1]
x_test = result[int(row):, :-1]
y_test = result[int(row):, -1][:,-1]
#reshape成 6天*3特征
X_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], amount_of_features))
X_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], amount_of_features))  
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (23644, 5, 4) (23644,) (2627, 5, 4) (2627,)

# %%
#建立LSTM模型 训练from tensorflow.keras.models import Model

inputs=Input(shape=(window, input_size))
model=Conv1D(filters = lstm_units, kernel_size = 1, activation = 'sigmoid')(inputs)#卷积层
model=MaxPooling1D(pool_size = window)(model)#池化层
model=Dropout(dropout)(model)#droupout层
model=Bidirectional(LSTM(lstm_units, activation='tanh'), name='bilstm')(model)#双向LSTM层
attention=Dense(lstm_units*2, activation='sigmoid', name='attention_vec')(model)#求解Attention权重
model=Multiply()([model, attention])#attention与LSTM对应数值相乘
outputs = Dense(1, activation='tanh')(model)
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])
model.summary()#展示模型结构
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 5, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 5, 16)     │         80 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 1, 16)     │          0 │ conv1d_1[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1, 16)     │          0 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bilstm              │ (None, 32)        │      4,224 │ dropout_1[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_vec       │ (None, 32)        │      1,056 │ bilstm[0][0]      │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32)        │          0 │ bilstm[0][0],     │
# │ (Multiply)          │                   │            │ attention_vec[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         33 │ multiply_1[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,393 (21.07 KB)
#  Trainable params: 5,393 (21.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(X_train, y_train, epochs=epoch, batch_size = 256,shuffle=False,validation_data=(X_test, y_test)) #训练模型epoch次
# Out:
# Epoch 1/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 2.1302e-04 - loss: 0.0944 - val_accuracy: 0.0000e+00 - val_loss: 0.0541
# Epoch 2/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.1302e-04 - loss: 0.0784 - val_accuracy: 0.0000e+00 - val_loss: 0.0535
# Epoch 3/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.1302e-04 - loss: 0.0743 - val_accuracy: 0.0000e+00 - val_loss: 0.0512
# Epoch 4/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.1302e-04 - loss: 0.0709 - val_accuracy: 0.0000e+00 - val_loss: 0.0490
# Epoch 5/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.1302e-04 - loss: 0.0674 - val_accuracy: 0.0000e+00 - val_loss: 0.0467
# Epoch 6/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0637 - val_accuracy: 0.0000e+00 - val_loss: 0.0446
# Epoch 7/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0593 - val_accuracy: 0.0000e+00 - val_loss: 0.0419
# Epoch 8/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 2.7455e-04 - loss: 0.0542 - val_accuracy: 0.0000e+00 - val_loss: 0.0385
# Epoch 9/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0481 - val_accuracy: 0.0000e+00 - val_loss: 0.0343
# Epoch 10/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0410 - val_accuracy: 0.0000e+00 - val_loss: 0.0282
# Epoch 11/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0332 - val_accuracy: 0.0000e+00 - val_loss: 0.0200
# Epoch 12/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0251 - val_accuracy: 0.0000e+00 - val_loss: 0.0112
# Epoch 13/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0178 - val_accuracy: 0.0000e+00 - val_loss: 0.0047
# Epoch 14/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0121 - val_accuracy: 0.0000e+00 - val_loss: 0.0021
# Epoch 15/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0077 - val_accuracy: 0.0000e+00 - val_loss: 0.0016
# Epoch 16/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0057 - val_accuracy: 0.0000e+00 - val_loss: 0.0015
# Epoch 17/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0050 - val_accuracy: 0.0000e+00 - val_loss: 0.0013
# Epoch 18/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0048 - val_accuracy: 0.0000e+00 - val_loss: 0.0012
# Epoch 19/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0047 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 20/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0044 - val_accuracy: 0.0000e+00 - val_loss: 0.0011
# Epoch 21/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0043 - val_accuracy: 0.0000e+00 - val_loss: 0.0010
# Epoch 22/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0041 - val_accuracy: 0.0000e+00 - val_loss: 9.4317e-04
# Epoch 23/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0040 - val_accuracy: 0.0000e+00 - val_loss: 8.8612e-04
# Epoch 24/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0041 - val_accuracy: 0.0000e+00 - val_loss: 8.2397e-04
# Epoch 25/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0038 - val_accuracy: 0.0000e+00 - val_loss: 8.4095e-04
# Epoch 26/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0037 - val_accuracy: 0.0000e+00 - val_loss: 8.0146e-04
# Epoch 27/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0037 - val_accuracy: 0.0000e+00 - val_loss: 7.9826e-04
# Epoch 28/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0035 - val_accuracy: 0.0000e+00 - val_loss: 7.1127e-04
# Epoch 29/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0034 - val_accuracy: 0.0000e+00 - val_loss: 6.4593e-04
# Epoch 30/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0034 - val_accuracy: 0.0000e+00 - val_loss: 6.1377e-04
# Epoch 31/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0033 - val_accuracy: 0.0000e+00 - val_loss: 5.9636e-04
# Epoch 32/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0033 - val_accuracy: 0.0000e+00 - val_loss: 5.6471e-04
# Epoch 33/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0031 - val_accuracy: 0.0000e+00 - val_loss: 5.5585e-04
# Epoch 34/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0031 - val_accuracy: 0.0000e+00 - val_loss: 4.3090e-04
# Epoch 35/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0031 - val_accuracy: 0.0000e+00 - val_loss: 4.4103e-04
# Epoch 36/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0030 - val_accuracy: 0.0000e+00 - val_loss: 4.1630e-04
# Epoch 37/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0028 - val_accuracy: 0.0000e+00 - val_loss: 3.4017e-04
# Epoch 38/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0028 - val_accuracy: 0.0000e+00 - val_loss: 3.6473e-04
# Epoch 39/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0026 - val_accuracy: 0.0000e+00 - val_loss: 3.0543e-04
# Epoch 40/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0027 - val_accuracy: 0.0000e+00 - val_loss: 2.8068e-04
# Epoch 41/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0025 - val_accuracy: 0.0000e+00 - val_loss: 2.4035e-04
# Epoch 42/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0025 - val_accuracy: 0.0000e+00 - val_loss: 2.2748e-04
# Epoch 43/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0025 - val_accuracy: 0.0000e+00 - val_loss: 2.2498e-04
# Epoch 44/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0024 - val_accuracy: 0.0000e+00 - val_loss: 1.8553e-04
# Epoch 45/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0024 - val_accuracy: 0.0000e+00 - val_loss: 1.7890e-04
# Epoch 46/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0023 - val_accuracy: 0.0000e+00 - val_loss: 1.6413e-04
# Epoch 47/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0022 - val_accuracy: 0.0000e+00 - val_loss: 1.6828e-04
# Epoch 48/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0022 - val_accuracy: 0.0000e+00 - val_loss: 1.5751e-04
# Epoch 49/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0022 - val_accuracy: 0.0000e+00 - val_loss: 1.5053e-04
# Epoch 50/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0022 - val_accuracy: 0.0000e+00 - val_loss: 1.4804e-04
# Epoch 51/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0021 - val_accuracy: 0.0000e+00 - val_loss: 1.4940e-04
# Epoch 52/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 2.7455e-04 - loss: 0.0021 - val_accuracy: 0.0000e+00 - val_loss: 1.4057e-04
# Epoch 53/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0021 - val_accuracy: 0.0000e+00 - val_loss: 1.4324e-04
# Epoch 54/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 2.7455e-04 - loss: 0.0021 - val_accuracy: 0.0000e+00 - val_loss: 1.4606e-04
# Epoch 55/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0020 - val_accuracy: 0.0000e+00 - val_loss: 1.4346e-04
# Epoch 56/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0020 - val_accuracy: 0.0000e+00 - val_loss: 1.4210e-04
# Epoch 57/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0020 - val_accuracy: 0.0000e+00 - val_loss: 1.4339e-04
# Epoch 58/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0020 - val_accuracy: 0.0000e+00 - val_loss: 1.4315e-04
# Epoch 59/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0020 - val_accuracy: 0.0000e+00 - val_loss: 1.4079e-04
# Epoch 60/60
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.7455e-04 - loss: 0.0019 - val_accuracy: 0.0000e+00 - val_loss: 1.4326e-04

# %%
#迭代图像
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epoch)
plt.plot(epochs_range, loss, label='Train Loss')
plt.plot(epochs_range, val_loss, label='Test Loss')
plt.legend(loc='upper right')
plt.title('Train and Val Loss')
plt.show()

# %%
#在训练集上的拟合结果
y_train_predict=model.predict(X_train)
y_train_predict=y_train_predict[:,0]
draw=pd.concat([pd.DataFrame(y_train),pd.DataFrame(y_train_predict)],axis=1)
draw.iloc[200:500,0].plot(figsize=(12,6))
draw.iloc[200:500,1].plot(figsize=(12,6))
plt.legend(('real', 'predict'),fontsize='15')
plt.title("Train Data",fontsize='30') #添加标题
# Out:
# 739/739 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Text(0.5, 1.0, 'Train Data')

# %%
#在测试集上的预测
y_test_predict=model.predict(X_test)
y_test_predict=y_test_predict[:,0]
draw=pd.concat([pd.DataFrame(y_test),pd.DataFrame(y_test_predict)],axis=1);
draw.iloc[200:500,0].plot(figsize=(12,6))
draw.iloc[200:500,1].plot(figsize=(12,6))
plt.legend(('real', 'predict'),loc='upper right',fontsize='15')
plt.title("Test Data",fontsize='30') #添加标题
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Text(0.5, 1.0, 'Test Data')

# %%
#输出结果
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100
def up_down_accuracy(y_true, y_pred):
    y_var_test=y_true[1:]-y_true[:len(y_true)-1]#实际涨跌
    y_var_predict=y_pred[1:]-y_pred[:len(y_pred)-1]#原始涨跌
    txt=np.zeros(len(y_var_test))
    for i in range(len(y_var_test-1)):#计算数量
        txt[i]=np.sign(y_var_test[i])==np.sign(y_var_predict[i])
    result=sum(txt)/len(txt)
    return result
print('训练集上的MAE/MSE/MAPE/涨跌准确率')
print(mean_absolute_error(y_train_predict, y_train))
print(mean_squared_error(y_train_predict, y_train) )
print(mape(y_train_predict, y_train) )
print(up_down_accuracy(y_train_predict,y_train))
print('测试集上的MAE/MSE/MAPE/涨跌准确率')
print(mean_absolute_error(y_test_predict, y_test))
print(mean_squared_error(y_test_predict, y_test) )
print(mape(y_test_predict,  y_test) )
print(up_down_accuracy(y_test_predict,y_test))
# Out:
# 训练集上的MAE/MSE/MAPE/涨跌准确率
# 0.022644036830335123
# 0.000897330628640549
# 5.5043392147393915
# 0.4326016157002073
# 测试集上的MAE/MSE/MAPE/涨跌准确率
# 0.009675687729920683
# 0.00014326457405429947
# 1.3549763593616706
# 0.40327494287890325
